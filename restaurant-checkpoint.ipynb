# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv('restaurant_data.csv')
df1
# Out:
#                  Name  Location   Cuisine  Rating  Seating Capacity  \
# 0        Restaurant 0     Rural  Japanese     4.0                38
# 1        Restaurant 1  Downtown   Mexican     3.2                76
# 2        Restaurant 2     Rural   Italian     4.7                48
# 3        Restaurant 3     Rural   Italian     4.4                34
# 4        Restaurant 4  Downtown  Japanese     4.9                88
# ...               ...       ...       ...     ...               ...
# 8363  Restaurant 8363  Suburban    Indian     3.4                54
# 8364  Restaurant 8364     Rural    Indian     3.7                49
# 8365  Restaurant 8365  Downtown   Italian     4.7                88
# 8366  Restaurant 8366     Rural  American     3.1                31
# 8367  Restaurant 8367     Rural  Japanese     4.0                33
#
#       Average Meal Price  Marketing Budget  Social Media Followers  \
# 0                  73.98              2224                   23406
# ...

# %%
df1.shape
# Out:
# (8368, 17)

# %%
df2=df1.pivot_table(index='Location', columns='Cuisine', values='Revenue', aggfunc='sum')
df2
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Downtown  3.644919e+08  5.273301e+08  2.947696e+08  4.398571e+08
# Rural     1.693173e+08  2.761691e+08  1.450285e+08  2.158551e+08
# Suburban  2.661487e+08  3.718533e+08  2.400688e+08  3.231328e+08
#
# Cuisine       Japanese       Mexican
# Location
# Downtown  5.482684e+08  2.699112e+08
# Rural     3.097512e+08  1.272155e+08
# Suburban  4.026107e+08  1.982191e+08

# %%
df2.sort_values(['American'],ascending=False)
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Downtown  3.644919e+08  5.273301e+08  2.947696e+08  4.398571e+08
# Suburban  2.661487e+08  3.718533e+08  2.400688e+08  3.231328e+08
# Rural     1.693173e+08  2.761691e+08  1.450285e+08  2.158551e+08
#
# Cuisine       Japanese       Mexican
# Location
# Downtown  5.482684e+08  2.699112e+08
# Suburban  4.026107e+08  1.982191e+08
# Rural     3.097512e+08  1.272155e+08

# %%
df2.plot(kind='barh')
# Out:
# <Axes: ylabel='Location'>

# %%
df2.T
# Out:
# Location      Downtown         Rural      Suburban
# Cuisine
# American  3.644919e+08  1.693173e+08  2.661487e+08
# French    5.273301e+08  2.761691e+08  3.718533e+08
# Indian    2.947696e+08  1.450285e+08  2.400688e+08
# Italian   4.398571e+08  2.158551e+08  3.231328e+08
# Japanese  5.482684e+08  3.097512e+08  4.026107e+08
# Mexican   2.699112e+08  1.272155e+08  1.982191e+08

# %%
df4=df3.T

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='Cuisine'>

# %%
df4
# Out:
# Location      Downtown
# Cuisine
# American  3.644919e+08
# French    5.273301e+08
# Indian    2.947696e+08
# Italian   4.398571e+08
# Japanese  5.482684e+08
# Mexican   2.699112e+08

# %%
df4.plot(kind='pie', y='Downtown',title='Revenue/Cuisine in Downtown',figsize=(4,5), fontsize=10, legend=False,explode=(0,0,0,0,0.1,0), autopct='%1.1f%%');

# %%
df_i=df1.pivot_table(index='Location', columns='Cuisine', values='Revenue', aggfunc='sum')
df_i
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Downtown  3.644919e+08  5.273301e+08  2.947696e+08  4.398571e+08
# Rural     1.693173e+08  2.761691e+08  1.450285e+08  2.158551e+08
# Suburban  2.661487e+08  3.718533e+08  2.400688e+08  3.231328e+08
#
# Cuisine       Japanese       Mexican
# Location
# Downtown  5.482684e+08  2.699112e+08
# Rural     3.097512e+08  1.272155e+08
# Suburban  4.026107e+08  1.982191e+08

# %%
df=df_i[df_i.index.isin(['Rural'])]
df
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Rural     1.693173e+08  2.761691e+08  1.450285e+08  2.158551e+08
#
# Cuisine       Japanese       Mexican
# Location
# Rural     3.097512e+08  1.272155e+08

# %%
df_l=df.T
df_l
# Out:
# Location         Rural
# Cuisine
# American  1.693173e+08
# French    2.761691e+08
# Indian    1.450285e+08
# Italian   2.158551e+08
# Japanese  3.097512e+08
# Mexican   1.272155e+08

# %%
df_l.plot(kind='pie', y='Rural',title='Revenue/Cuisine in Rural', figsize=(4,5), fontsize=10, legend=False,explode=(0,0,0,0,0.1,0), autopct='%1.1f%%');

# %%
df_g=df1.pivot_table(index='Location', columns='Cuisine', values='Revenue', aggfunc='sum')
df_g
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Downtown  3.644919e+08  5.273301e+08  2.947696e+08  4.398571e+08
# Rural     1.693173e+08  2.761691e+08  1.450285e+08  2.158551e+08
# Suburban  2.661487e+08  3.718533e+08  2.400688e+08  3.231328e+08
#
# Cuisine       Japanese       Mexican
# Location
# Downtown  5.482684e+08  2.699112e+08
# Rural     3.097512e+08  1.272155e+08
# Suburban  4.026107e+08  1.982191e+08

# %%
df=df_g[df_i.index.isin(['Suburban'])]
df
# Out:
# Cuisine       American        French        Indian       Italian  \
# Location
# Suburban  2.661487e+08  3.718533e+08  2.400688e+08  3.231328e+08
#
# Cuisine       Japanese       Mexican
# Location
# Suburban  4.026107e+08  1.982191e+08

# %%
df7=df.T
df7
# Out:
# Location      Suburban
# Cuisine
# American  2.661487e+08
# French    3.718533e+08
# Indian    2.400688e+08
# Italian   3.231328e+08
# Japanese  4.026107e+08
# Mexican   1.982191e+08

# %%
df7.plot(kind='pie', y='Suburban',title='Revenue/Cuisine in Suburban', figsize=(4,5), fontsize=10, legend=False,explode=(0,0,0,0,0.1,0), autopct='%1.1f%%');

# %%
df1.inf0
# Out:
# <bound method DataFrame.info of                  Name  Location   Cuisine  Rating  Seating Capacity  \
# 0        Restaurant 0     Rural  Japanese     4.0                38
# 1        Restaurant 1  Downtown   Mexican     3.2                76
# 2        Restaurant 2     Rural   Italian     4.7                48
# 3        Restaurant 3     Rural   Italian     4.4                34
# 4        Restaurant 4  Downtown  Japanese     4.9                88
# ...               ...       ...       ...     ...               ...
# 8363  Restaurant 8363  Suburban    Indian     3.4                54
# 8364  Restaurant 8364     Rural    Indian     3.7                49
# 8365  Restaurant 8365  Downtown   Italian     4.7                88
# 8366  Restaurant 8366     Rural  American     3.1                31
# 8367  Restaurant 8367     Rural  Japanese     4.0                33
#
#       Average Meal Price  Marketing Budget  Social Media Followers  \
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# Name                      0
# Location                  0
# Cuisine                   0
# Rating                    0
# Seating Capacity          0
# Average Meal Price        0
# Marketing Budget          0
# Social Media Followers    0
# Chef Experience Years     0
# Number of Reviews         0
# Avg Review Length         0
# Ambience Score            0
# Service Quality Score     0
# Parking Availability      0
# Weekend Reservations      0
# Weekday Reservations      0
# Revenue                   0
# dtype: int64

# %%
df1.describe().T
# Out:
#                          count           mean            std            min  \
# Rating                  8368.0       4.008258       0.581474       3.000000
# Seating Capacity        8368.0      60.212835      17.399488      30.000000
# Average Meal Price      8368.0      47.896659      14.336767      25.000000
# Marketing Budget        8368.0    3218.254900    1824.896053     604.000000
# Social Media Followers  8368.0   36190.621773   18630.153330    5277.000000
# Chef Experience Years   8368.0      10.051984       5.516606       1.000000
# Number of Reviews       8368.0     523.010397     277.215127      50.000000
# Avg Review Length       8368.0     174.769974      71.998060      50.011717
# Ambience Score          8368.0       5.521283       2.575442       1.000000
# Service Quality Score   8368.0       5.508772       2.586552       1.000000
# Weekend Reservations    8368.0      29.491754      20.025415       0.000000
# ...

# %%
hj=df1.select_dtypes(include='number').corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(hj, annot=True)
# Out:
# <Axes: >
